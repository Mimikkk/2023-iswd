# %% [markdown]
# Criteria description:
# * **The total financial cost (criterion C1)** = This criterion represents the total of the expenses which are necessary to cover all the technical costs incurred before, during and after dumping of the radioactive wastes
# * **The "polluter-pays principle" (criteria C2 z and C3)**, it corresponds to the electronuclear production generating the wastes to be buried into the repository:
#     - **C2** represents the costs incurred by the present consumers;
#     - **C3** = costs to be supported by the future consumers (although they did not take advantage of the t = 0 -> 30 year electronuclear production)
# * **Financial risk due to overcosts (C4)**: related to a wrong assessment: for example, in the case of the kWh-financing
# (F1), the risk is to be short of payments after the thirty year fee raising for the fund
#
# All criteria are cost-type.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pulp import *

# %% [markdown]
# ### Setup

# %%
data = pd.read_csv("nuclear-waste-management.csv", index_col=0)
data
# Out:
#       C1    C2    C3    C4
# 1   0.60  0.93  0.00  0.73
# 2   0.66  0.55  0.45  0.49
# 3   1.00  0.45  0.57  0.50
# 4   0.48  0.87  0.00  0.75
# 5   0.62  0.40  0.56  0.50
# 6   0.78  0.27  0.71  0.50
# 7   0.40  0.90  0.00  0.82
# 8   0.64  0.44  0.54  0.54
# 9   0.65  0.30  0.71  0.55
# 10  0.45  0.86  0.00  0.73
# 11  0.61  0.54  0.38  0.49
# 12  0.74  0.25  0.80  0.49
# 13  0.48  0.97  0.00  0.91
# 14  0.69  0.49  0.56  0.61
# 15  0.87  0.03  1.00  0.61
# 16  0.44  0.95  0.00  0.90
# 17  0.68  0.40  0.65  0.60
# 18  0.76  0.06  1.00  0.60
# 19  0.35  0.91  0.00  0.98
# 20  0.64  0.22  0.81  0.65
# 21  0.83  0.25  0.80  0.65
# 22  0.32  0.83  0.00  0.94
# 23  0.59  0.24  0.70  0.63
# 24  0.73  0.03  1.00  0.63
# 25  0.34  1.00  1.00  1.00
# 26  0.71  0.25  0.88  0.67
# 27  0.80  0.06  1.00  0.67

# %%
u = pd.DataFrame.from_dict({
    f"C{criterion}": {
        u_arg: LpVariable(
            name=f"{criterion}_{u_arg}", lowBound=0, upBound=1, cat="Continuous"
        )
        for u_arg in range(101)
    }
    for criterion in range(1, 5)
})

u
# Out:
#         C1     C2     C3     C4
# 0      1_0    2_0    3_0    4_0
# 1      1_1    2_1    3_1    4_1
# 2      1_2    2_2    3_2    4_2
# 3      1_3    2_3    3_3    4_3
# 4      1_4    2_4    3_4    4_4
# ..     ...    ...    ...    ...
# 96    1_96   2_96   3_96   4_96
# 97    1_97   2_97   3_97   4_97
# 98    1_98   2_98   3_98   4_98
# 99    1_99   2_99   3_99   4_99
# 100  1_100  2_100  3_100  4_100
#
# [101 rows x 4 columns]

# %%
min_max = pd.DataFrame.from_dict({
    f"C{criterion}": {
        "best": min(data[f"C{criterion}"]),
        "worst": max(data[f"C{criterion}"]),
    }
    for criterion in range(1, 5)
})

min_max
# Out:
#          C1    C2   C3    C4
# best   0.32  0.03  0.0  0.49
# worst  1.00  1.00  1.0  1.00

# %%
def add_to_reference_ranking(model, a: int, b: int, epsilon: None | LpVariable = None) -> None:
    a_variant = (data.loc[a] * 100).astype(np.int8)
    b_variant = (data.loc[b] * 100).astype(np.int8)

    if epsilon is None:
        model.addConstraint(
            (
                u.C1[a_variant.C1] + u.C2[a_variant.C2] + u.C3[a_variant.C3] + u.C4[a_variant.C4]
                == u.C1[b_variant.C1] + u.C2[b_variant.C2] + u.C3[b_variant.C3] + u.C4[b_variant.C4]
            ),
            # f"#{a} indifferent to {b}",
        )
    else:
        model.addConstraint(
            (
                u.C1[a_variant.C1] + u.C2[a_variant.C2] + u.C3[a_variant.C3] + u.C4[a_variant.C4]
                >= u.C1[b_variant.C1] + u.C2[b_variant.C2] + u.C3[b_variant.C3] + u.C4[b_variant.C4] + epsilon
            ),
            # f"#{a} over {b}",
        )

# %%
def normalization_condition(model) -> None:
    limits = (min_max * 100).astype(np.uint8)

    model.addConstraint(
        (u.C1[limits.C1.best] + u.C2[limits.C2.best] + u.C3[limits.C3.best] + u.C4[limits.C4.best] == 1),
        "#normalization"
    )

    model.addConstraint(u.C1[limits.C1.worst] == 0, "#criterion 1 worst value")
    model.addConstraint(u.C2[limits.C2.worst] == 0, "#criterion 2 worst value")
    model.addConstraint(u.C3[limits.C3.worst] == 0, "#criterion 3 worst value")
    model.addConstraint(u.C4[limits.C4.worst] == 0, "#criterion 4 worst value")

# %%
def monotonicity_and_non_negativity_condition(model) -> None:  

    for criterion in data.columns:
        values = sorted(set((data[criterion] * 100).astype(np.int8)))

        for c_value in values:
            model += u[criterion][c_value] >= 0
        
        for i in range(1, len(values)):
            model += u[criterion][values[i - 1]] >= u[criterion][values[i]]

# %% [markdown]
# ### UTA Method

# %%
def solver_main_function() -> LpProblem:
    model = LpProblem(name="nuclear-waste-management", sense=LpMaximize)
    epsilon = LpVariable(name="epsilon", lowBound=0, cat="Continuous")

    # constraints
    normalization_condition(model)
    monotonicity_and_non_negativity_condition(model)

    # reference ranking
    # 11 > 14 = 2 > 19 = 25
    # 10 > 19
    add_to_reference_ranking(model, 11, 14, epsilon)
    add_to_reference_ranking(model, 2, 19, epsilon)

    add_to_reference_ranking(model, 14, 2)

    add_to_reference_ranking(model, 10, 19, epsilon)
    add_to_reference_ranking(model, 25, 19)

    model += epsilon

    return model, epsilon

# solving
model, _ = solver_main_function()
status = model.solve()

print(f"status: {model.status}, {LpStatus[model.status]}")
print(f"objective: {model.objective.value()}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/a1f260f2a4af40beb77b916e5471a848-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/a1f260f2a4af40beb77b916e5471a848-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 163 COLUMNS
# At line 435 RHS
# At line 594 BOUNDS
# At line 671 ENDATA
# Problem MODEL has 158 rows, 77 columns and 269 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 45 (-113) rows, 45 (-32) columns and 113 (-156) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 7.2242825e-05 ( 0.0072242825%) - largest zero change 7.1142212e-05
# 0  Obj -0 Dual inf 0.99992676 (1)
# 31  Obj 0.9993679 Primal inf 1.999998 (2)
# 42  Obj 0.39963804
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
#
# status: 1, Optimal
# objective: 0.4

# %%
ranking = pd.DataFrame(data.copy())

for criterion in data.columns:
    ranking[f"U({criterion})"] = [0 for _ in range(27)]
ranking["U"] = [0 for _ in range(27)]

for criterion in data.columns:
    for variant in data.index:
        u_arg = (data[criterion][variant] * 100).astype(np.int8)
        ranking[f"U({criterion})"][variant] += round(u[criterion][u_arg].value(), 10)

for variant in data.index:
    ranking["U"][variant] = np.sum(ranking.loc[variant][5:])



ranking.sort_values('U', ascending=False)
# Out:
# /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/ipykernel_15807/2644740598.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking[f"U({criterion})"][variant] += round(u[criterion][u_arg].value(), 10)
# /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/ipykernel_15807/2644740598.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking["U"][variant] = np.sum(ranking.loc[variant][5:])
#       C1    C2    C3    C4  U(C1)  U(C2)  U(C3)  U(C4)    U
# 12  0.74  0.25  0.80  0.49    0.0    0.2      0    0.6  0.8
# 11  0.61  0.54  0.38  0.49    0.2    0.2      0    0.6  0.8
# 14  0.69  0.49  0.56  0.61    0.0    0.2      0    0.4  0.6
# 26  0.71  0.25  0.88  0.67    0.0    0.2      0    0.4  0.6
# 24  0.73  0.03  1.00  0.63    0.0    0.2      0    0.4  0.6
# 23  0.59  0.24  0.70  0.63    0.2    0.2      0    0.4  0.6
# 21  0.83  0.25  0.80  0.65    0.0    0.2      0    0.4  0.6
# 20  0.64  0.22  0.81  0.65    0.0    0.2      0    0.4  0.6
# 18  0.76  0.06  1.00  0.60    0.0    0.2      0    0.4  0.6
# 17  0.68  0.40  0.65  0.60    0.0    0.2      0    0.4  0.6
# 15  0.87  0.03  1.00  0.61    0.0    0.2      0    0.4  0.6
# 27  0.80  0.06  1.00  0.67    0.0    0.2      0    0.4  0.6
# 9   0.65  0.30  0.71  0.55    0.0    0.2      0    0.4  0.6
# 8   0.64  0.44  0.54  0.54    0.0    0.2      0    0.4  0.6
# 6   0.78  0.27  0.71  0.50    0.0    0.2      0    0.4  0.6
# 5   0.62  0.40  0.56  0.50    0.0    0.2      0    0.4  0.6
# 3   1.00  0.45  0.57  0.50    0.0    0.2      0    0.4  0.6
# 2   0.66  0.55  0.45  0.49    0.0    0.0      0    0.6  0.6
# 10  0.45  0.86  0.00  0.73    0.2    0.0      0    0.4  0.4
# 1   0.60  0.93  0.00  0.73    0.2    0.0      0    0.4  0.4
# 13  0.48  0.97  0.00  0.91    0.2    0.0      0    0.0  0.0
# 16  0.44  0.95  0.00  0.90    0.2    0.0      0    0.0  0.0
# 19  0.35  0.91  0.00  0.98    0.2    0.0      0    0.0  0.0
# 7   0.40  0.90  0.00  0.82    0.2    0.0      0    0.0  0.0
# 22  0.32  0.83  0.00  0.94    0.2    0.0      0    0.0  0.0
# 4   0.48  0.87  0.00  0.75    0.2    0.0      0    0.0  0.0
# 25  0.34  1.00  1.00  1.00    0.2    0.0      0    0.0  0.0

# %% [markdown]
# #### UTA GMS

# %%
def solver_uta_gms(a: int, b: int) -> LpProblem:
    model, epsilon = solver_main_function()

    add_to_reference_ranking(model, a, b, epsilon)

    status = model.solve()

    return model.objective.value()

epsilon_results = np.zeros((27, 27))
for i in range(epsilon_results.shape[0]):
    for j in range(epsilon_results.shape[1]):
        if i == j:
            continue
        result = solver_uta_gms(i + 1, j + 1)
        if result > 0:
            epsilon_results[i, j] = 1
        elif result == 0:
            epsilon_results[i, j] = 0
        else:
            epsilon_results[i, j] = -1

for i in range(epsilon_results.shape[0]):
    for j in range(epsilon_results.shape[1]):
        if i == j:
            continue
        if epsilon_results[i, j] >= 0 and epsilon_results[j, i] <= 0:
            print(f'necessary = ({i + 1}, {j + 1})')
        elif epsilon_results[i, j] >= 0:
            print(f'possible = ({i + 1}, {j + 1})')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/89befc01041e46b09d5803ac9a8f848f-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/89befc01041e46b09d5803ac9a8f848f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 133 (-145) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017286243
# 0  Obj -0 Dual inf 0.99982203 (1)
# 28  Obj 0.33268841
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 28 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/1dc73deb75144764b889b23fbcd448af-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/1dc73deb75144764b889b23fbcd448af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 132 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 33  Obj 0.99739456 Primal inf 14.399988 (12)
# 39  Obj 0.3326658
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 39 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/886a0084cbfb47ae9e198fcdc418b0b6-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/886a0084cbfb47ae9e198fcdc418b0b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 130 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 1.3315541 Primal inf 2.999994 (6)
# 42  Obj 0.39942476
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/68c257e6b4874ecc873ff0918610dcb9-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/68c257e6b4874ecc873ff0918610dcb9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 133 (-145) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 35  Obj 0.49944531 Primal inf 2.999994 (6)
# 40  Obj 0.3326658
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 40 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/fb984cf2738842e9b3fb9184a7185e27-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/fb984cf2738842e9b3fb9184a7185e27-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 1.4983802 Primal inf 6.499991 (9)
# 42  Obj 0.3326658
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3668c62383454ada9b462022377be27a-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3668c62383454ada9b462022377be27a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 130 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 0.99889343 Primal inf 1.999998 (2)
# 42  Obj 0.39942661
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/0cfdb90f2cf94a289a6674d57f904e96-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/0cfdb90f2cf94a289a6674d57f904e96-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 133 (-145) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 33  Obj 0.49945317 Primal inf 2.999994 (6)
# 38  Obj 0.33265889
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 38 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/088902ce41ef422b988ffb8d9e228d1c-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/088902ce41ef422b988ffb8d9e228d1c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 132 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 32  Obj 0.79863031 Primal inf 4.199993 (7)
# 37  Obj 0.33266565
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 37 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/dcff5538c3bd418c993f09c0c3f5163c-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/dcff5538c3bd418c993f09c0c3f5163c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 443 RHS
# At line 603 BOUNDS
# At line 680 ENDATA
# Problem MODEL has 159 rows, 77 columns and 274 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 129 (-145) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 2.5917744e-05 Primal inf 10.999989 (11)
# 32  Obj -0
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 32 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/cb3b65badfaf400fa867d68f1d05aed9-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/cb3b65badfaf400fa867d68f1d05aed9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 133 (-145) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 32  Obj 0.19938427
# Optimal - objective value 0.2
# After Postsolve, objective 0.2, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2 - 32 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/465a8047317043c4934e66214dc548a5-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/465a8047317043c4934e66214dc548a5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 34  Obj 0.59840246 Primal inf 3.399994 (6)
# 39  Obj 0.33268841
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 39 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/c427ba10a12a46028f902dcec3ebb389-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/c427ba10a12a46028f902dcec3ebb389-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 129 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 1.3315541 Primal inf 2.999994 (6)
# 42  Obj 0.39942476
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/c2d5ba7b309d4b10a87d3f48d29560eb-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/c2d5ba7b309d4b10a87d3f48d29560eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 133 (-145) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 0.33267189
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 31 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/7b81aa971e2c42ee9af705a9e3b9eb3a-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/7b81aa971e2c42ee9af705a9e3b9eb3a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 33  Obj 0.66536798 Primal inf 1.6666637 (3)
# 46  Obj 0.33267208
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 46 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/20140e60bbc3414cb31da5c51dddd068-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/20140e60bbc3414cb31da5c51dddd068-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 129 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 0.99889439 Primal inf 1.999998 (2)
# 42  Obj 0.39942409
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/8099b08a57e8486680879f61714c3547-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/8099b08a57e8486680879f61714c3547-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 132 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 0.79890827 Primal inf 5.799992 (8)
# 41  Obj 0.33266973
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 41 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/30501eb9bd8d422790689fbba464afd9-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/30501eb9bd8d422790689fbba464afd9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 33  Obj 1.1180144 Primal inf 9.19999 (10)
# 50  Obj 0.33266973
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 50 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/a0119e03462c4a8ba71f40b2fb6a9f2d-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/a0119e03462c4a8ba71f40b2fb6a9f2d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 130 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00016090306
# 0  Obj -0 Dual inf 0.99982203 (1)
# 32  Obj 1.4984197 Primal inf 3.499995 (5)
# 40  Obj 0.39944479
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 40 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/6a574ac6b13a4115b77dd6bf040ab8ee-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/6a574ac6b13a4115b77dd6bf040ab8ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 132 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 0.74889991 Primal inf 3.849992 (8)
# 44  Obj 0.33274519
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 44 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/a7e481e803904bafba218a94ecf51b2f-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/a7e481e803904bafba218a94ecf51b2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 0.74889991 Primal inf 3.849992 (8)
# 42  Obj 0.33274519
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/ebe86f9016d34e2eb17f4cf18c151e39-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/ebe86f9016d34e2eb17f4cf18c151e39-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 132 (-144) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Primal inf 0.999999 (1) Dual inf 0.99982203 (1)
# 31  Obj 0.99891999 Primal inf 1.999998 (2)
# 40  Obj 0.39942391
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 40 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/01b6a532e6a147f9a824704362572b23-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/01b6a532e6a147f9a824704362572b23-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 132 (-146) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 0.7487632 Primal inf 3.699993 (7)
# 45  Obj 0.2496437
# Optimal - objective value 0.25
# After Postsolve, objective 0.25, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.25 - 45 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/b4b357d9c2864452a6b6f0dd44f04296-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/b4b357d9c2864452a6b6f0dd44f04296-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 31  Obj 1.1180166 Primal inf 17.079985 (15)
# 45  Obj 0.33274902
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 45 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/605a1664e3ca4d6ea63816f1ab1610d8-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/605a1664e3ca4d6ea63816f1ab1610d8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 130 (-148) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00016090306
# 0  Obj -0 Dual inf 0.99982203 (1)
# 32  Obj 1.4984197 Primal inf 3.499995 (5)
# 40  Obj 0.39944479
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 40 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/e4b9e3f3196a46c1b7c20a4c533283ed-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/e4b9e3f3196a46c1b7c20a4c533283ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 32  Obj 1.1983588 Primal inf 8.199983 (17)
# 41  Obj 0.33274654
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 41 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3047cf7dcb534e288ba6bafa1a0c5444-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3047cf7dcb534e288ba6bafa1a0c5444-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 50 (-109) rows, 49 (-28) columns and 131 (-147) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00017696542 ( 0.017696542%) - largest zero change 0.00017124603
# 0  Obj -0 Dual inf 0.99982203 (1)
# 32  Obj 1.1983588 Primal inf 8.199983 (17)
# 44  Obj 0.33274654
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 44 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/ed1d629901854162a66ed7cf7657a079-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/ed1d629901854162a66ed7cf7657a079-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 121 (-157) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 31  Obj 0.49932366 Primal inf 0.999998 (2)
# 37  Obj 0.39942678
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 37 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/7b99ca7ae3b24c918e82262bfc831bdd-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/7b99ca7ae3b24c918e82262bfc831bdd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 121 (-157) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013629917
# 0  Obj -0 Dual inf 0.99985451 (1)
# 31  Obj 0.49931379 Primal inf 1.499997 (3)
# 41  Obj 0.28513661
# Optimal - objective value 0.28571429
# After Postsolve, objective 0.28571429, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2857142857 - 41 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3542359a984d4e70bae7131d7c6775ac-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3542359a984d4e70bae7131d7c6775ac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 120 (-158) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 33  Obj 0.49970974 Primal inf 2.499995 (5)
# 42  Obj 0.39950774
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/231f448bfe2c4812a6cd624681c8df62-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/231f448bfe2c4812a6cd624681c8df62-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 122 (-156) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013629917
# 0  Obj -0 Dual inf 0.99985451 (1)
# 31  Obj 0.49931866 Primal inf 1.499997 (3)
# 43  Obj -0
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 43 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/40f0623bdd9544b6bb65ed9f8f7c15b5-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/40f0623bdd9544b6bb65ed9f8f7c15b5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 120 (-158) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 33  Obj 0.49911496 Primal inf 1.499997 (3)
# 45  Obj 0.28513614
# Optimal - objective value 0.28571429
# After Postsolve, objective 0.28571429, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2857142857 - 45 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/86e7116629e24694b26b2c0da066d1cb-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/86e7116629e24694b26b2c0da066d1cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 120 (-158) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 34  Obj 0.49953297 Primal inf 1.499998 (2)
# 42  Obj 0.39950959
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/705b8e26923a44a1a8e34ab175541956-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/705b8e26923a44a1a8e34ab175541956-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 122 (-156) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 31  Obj 0.49931869 Primal inf 1.499997 (3)
# 41  Obj -0
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 41 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/0b0bab5dfd3c4679b46d99a003f93225-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/0b0bab5dfd3c4679b46d99a003f93225-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 121 (-157) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 31  Obj 0.49913217 Primal inf 1.499997 (3)
# 42  Obj 0.22185591
# Optimal - objective value 0.22222222
# After Postsolve, objective 0.22222222, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2222222222 - 42 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/e4f325227159405cac935cee09e2676f-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/e4f325227159405cac935cee09e2676f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 122 (-156) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 31  Obj 0.66579609 Primal inf 1.6666637 (3)
# 43  Obj 0.33287294
# Optimal - objective value 0.33333333
# After Postsolve, objective 0.33333333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3333333333 - 43 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/f481e4e6b0eb4a49a0181e97689ccf8c-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/f481e4e6b0eb4a49a0181e97689ccf8c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 120 (-156) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00014228442
# 0  Obj -0 Dual inf 0.99985451 (1)
# 4  Obj -0
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3feadf6eba3b4aa78d7acac2670172e0-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/3feadf6eba3b4aa78d7acac2670172e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 444 RHS
# At line 604 BOUNDS
# At line 681 ENDATA
# Problem MODEL has 159 rows, 77 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 46 (-113) rows, 45 (-32) columns and 118 (-158) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00014448565 ( 0.014448565%) - largest zero change 0.00013563277
# 0  Obj -0 Dual inf 0.99985451 (1)
# 31  Obj 0.24963668 Primal inf 4.399993 (7)
# 46  Obj 0.24944523
# Optimal - objective value 0.25
# After Postsolve, objective 0.25, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.25 - 46 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# ...
# Optimal objective 0.2857142857 - 49 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/622fcbc9b9f4401fa553e8358857756d-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/622fcbc9b9f4401fa553e8358857756d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 53 (-106) rows, 52 (-25) columns and 134 (-144) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00012729864 ( 0.012729864%) - largest zero change 9.6263582e-05
# 0  Obj -0 Dual inf 0.9998717 (1)
# 32  Obj 1.498667 Primal inf 7.1999919 (8)
# 53  Obj 0.39951497
# Optimal - objective value 0.4
# After Postsolve, objective 0.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4 - 53 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/annapralat/Studies/SI/ISWD/.venv/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/65ce289608bd45dc8c775f62e6b7e607-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/hv/9h4vvcdx1px2mm2jfg7k1_0m0000gn/T/65ce289608bd45dc8c775f62e6b7e607-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 164 COLUMNS
# At line 445 RHS
# At line 605 BOUNDS
# At line 682 ENDATA
# Problem MODEL has 159 rows, 77 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 53 (-106) rows, 52 (-25) columns and 136 (-142) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 0.00012729864 ( 0.012729864%) - largest zero change 9.6possible = (1, 2)
# possible = (1, 3)
# possible = (1, 4)
# possible = (1, 5)
# possible = (1, 6)
# possible = (1, 7)
# possible = (1, 8)
# possible = (1, 9)
# possible = (1, 10)
# possible = (1, 11)
# possible = (1, 12)
# possible = (1, 13)
# possible = (1, 14)
# possible = (1, 15)
# possible = (1, 16)
# possible = (1, 17)
# possible = (1, 18)
# possible = (1, 19)
# possible = (1, 20)
# possible = (1, 21)
# possible = (1, 22)
# possible = (1, 23)
# possible = (1, 24)
# possible = (1, 25)
# possible = (1, 26)
# possible = (1, 27)
# possible = (2, 1)
# possible = (2, 3)
# possible = (2, 4)
# possible = (2, 5)
# possible = (2, 6)
# possible = (2, 7)
# possible = (2, 8)
# possible = (2, 9)
# possible = (2, 10)
# possible = (2, 11)
# possible = (2, 12)
# possible = (2, 13)
# necessary = (2, 14)
# possible = (2, 15)
# possible = (2, 16)
# possible = (2, 17)
# possible = (2, 18)
# necessary = (2, 19)
# possible = (2, 20)
# possible = (2, 21)
# possible = (2, 22)
# possible = (2, 23)
# possible = (2, 24)
# necessary = (2, 25)
# possible = (2, 26)
# possible = (2, 27)
# possible = (3, 1)
# possible = (3, 2)
# possible = (3, 4)
# possible = (3, 5)
# possible = (3, 6)
# possible = (3, 7)
# possible = (3, 8)
# possible = (3, 9)
# possible = (3, 10)
# possible = (3, 11)
# possible = (3, 12)
# possible = (3, 13)
# possible = (3, 14)
# possible = (3, 15)
# possible = (3, 16)
# possible = (3, 17)
# possible = (3, 18)
# possible = (3, 19)
# possible = (3, 20)
# possible = (3, 21)
# possible = (3, 22)
# possible = (3, 23)
# possible = (3, 24)
# possible = (3, 25)
# possible = (3, 26)
# possible = (3, 27)
# possible = (4, 1)
# possible = (4, 2)
# possible = (4, 3)
# possible = (4, 5)
# possible = (4, 6)
# possible = (4, 7)
# possible = (4, 8)
# possible = (4, 9)
# possible = (4, 10)
# possible = (4, 11)
# possible = (4, 12)
# necessary = (4, 13)
# possible = (4, 14)
# possible = (4, 15)
# possible = (4, 16)
# possible = (4, 17)
# possible = (4, 18)
# possible = (4, 19)
# possible = (4, 20)
# possible = (4, 21)
# possible = (4, 22)
# possible = (4, 23)
# possible = (4, 24)
# possible = (4, 25)
# possible = (4, 26)
# possible = (4, 27)
# possible = (5, 1)
# necessary = (5, 2)
# necessary = (5, 3)
# possible = (5, 4)
# possible = (5, 6)
# possible = (5, 7)
# possible = (5, 8)
# possible = (5, 9)
# possible = (5, 10)
# possible = (5, 11)
# possible = (5, 12)
# possible = (5, 13)
# necessary = (5, 14)
# possible = (5, 15)
# possible = (5, 16)
# necessary = (5, 17)
# possible = (5, 18)
# necessary = (5, 19)
# possible = (5, 20)
# possible = (5, 21)
# possible = (5, 22)
# possible = (5, 23)
# possible = (5, 24)
# necessary = (5, 25)
# possible = (5, 26)
# possible = (5, 27)
# possible = (6, 1)
# possible = (6, 2)
# possible = (6, 3)
# possible = (6, 4)
# possible = (6, 5)
# possible = (6, 7)
# possible = (6, 8)
# possible = (6, 9)
# possible = (6, 10)
# possible = (6, 11)
# possible = (6, 12)
# possible = (6, 13)
# possible = (6, 14)
# possible = (6, 15)
# possible = (6, 16)
# possible = (6, 17)
# possible = (6, 18)
# possible = (6, 19)
# possible = (6, 20)
# possible = (6, 21)
# possible = (6, 22)
# possible = (6, 23)
# possible = (6, 24)
# possible = (6, 25)
# possible = (6, 26)
# possible = (6, 27)
# possible = (7, 1)
# possible = (7, 2)
# possible = (7, 3)
# possible = (7, 4)
# possible = (7, 5)
# possible = (7, 6)
# possible = (7, 8)
# possible = (7, 9)
# possible = (7, 10)
# possible = (7, 11)
# possible = (7, 12)
# necessary = (7, 13)
# possible = (7, 14)
# possible = (7, 15)
# necessary = (7, 16)
# possible = (7, 17)
# possible = (7, 18)
# possible = (7, 19)
# possible = (7, 20)
# possible = (7, 21)
# possible = (7, 22)
# possible = (7, 23)
# possible = (7, 24)
# possible = (7, 25)
# possible = (7, 26)
# possible = (7, 27)
# possible = (8, 1)
# necessary = (8, 2)
# possible = (8, 3)
# possible = (8, 4)
# possible = (8, 5)
# possible = (8, 6)
# possible = (8, 7)
# possible = (8, 9)
# possible = (8, 10)
# possible = (8, 11)
# possible = (8, 12)
# possible = (8, 13)
# necessary = (8, 14)
# possible = (8, 15)
# possible = (8, 16)
# possible = (8, 17)
# possible = (8, 18)
# necessary = (8, 19)
# possible = (8, 20)
# possible = (8, 21)
# possible = (8, 22)
# possible = (8, 23)
# possible = (8, 24)
# necessary = (8, 25)
# possible = (8, 26)
# possible = (8, 27)
# possible = (9, 1)
# possible = (9, 2)
# possible = (9, 3)
# possible = (9, 4)
# possible = (9, 5)
# possible = (9, 6)
# possible = (9, 7)
# possible = (9, 8)
# possible = (9, 10)
# possible = (9, 11)
# possible = (9, 12)
# possible = (9, 13)
# possible = (9, 14)
# possible = (9, 15)
# possible = (9, 16)
# possible = (9, 17)
# possible = (9, 18)
# possible = (9, 19)
# possible = (9, 20)
# possible = (9, 21)
# possible = (9, 22)
# possible = (9, 23)
# possible = (9, 24)
# possible = (9, 25)
# possible = (9, 26)
# possible = (9, 27)
# necessary = (10, 1)
# possible = (10, 2)
# possible = (10, 3)
# necessary = (10, 4)
# possible = (10, 5)
# possible = (10, 6)
# possible = (10, 7)
# possible = (10, 8)
# possible = (10, 9)
# possible = (10, 11)
# possible = (10, 12)
# necessary = (10, 13)
# possible = (10, 14)
# possible = (10, 15)
# possible = (10, 16)
# possible = (10, 17)
# possible = (10, 18)
# necessary = (10, 19)
# possible = (10, 20)
# possible = (10, 21)
# possible = (10, 22)
# possible = (10, 23)
# possible = (10, 24)
# necessary = (10, 25)
# possible = (10, 26)
# possible = (10, 27)
# possible = (11, 1)
# necessary = (11, 2)
# possible = (11, 3)
# possible = (11, 4)
# possible = (11, 5)
# possible = (11, 6)
# possible = (11, 7)
# possible = (11, 8)
# possible = (11, 9)
# possible = (11, 10)
# possible = (11, 12)
# possible = (11, 13)
# necessary = (11, 14)
# possible = (11, 15)
# possible = (11, 16)
# possible = (11, 17)
# possible = (11, 18)
# necessary = (11, 19)
# possible = (11, 20)
# possible = (11, 21)
# possible = (11, 22)
# possible = (11, 23)
# possible = (11, 24)
# necessary = (11, 25)
# possible = (11, 26)
# possible = (11, 27)
# possible = (12, 1)
# possible = (12, 2)
# possible = (12, 3)
# possible = (12, 4)
# possible = (12, 5)
# possible = (12, 6)
# possible = (12, 7)
# possible = (12, 8)
# possible = (12, 9)
# possible = (12, 10)
# possible = (12, 11)
# possible = (12, 13)
# possible = (12, 14)
# possible = (12, 15)
# possible = (12, 16)
# possible = (12, 17)
# possible = (12, 18)
# possible = (12, 19)
# possible = (12, 20)
# necessary = (12, 21)
# possible = (12, 22)
# possible = (12, 23)
# possible = (12, 24)
# possible = (12, 25)
# possible = (12, 26)
# possible = (12, 27)
# possible = (13, 1)
# possible = (13, 2)
# possible = (13, 3)
# possible = (13, 4)
# possible = (13, 5)
# possible = (13, 6)
# possible = (13, 7)
# possible = (13, 8)
# possible = (13, 9)
# possible = (13, 10)
# possible = (13, 11)
# possible = (13, 12)
# possible = (13, 14)
# possible = (13, 15)
# possible = (13, 16)
# possible = (13, 17)
# possible = (13, 18)
# possible = (13, 19)
# possible = (13, 20)
# possible = (13, 21)
# possible = (13, 22)
# possible = (13, 23)
# possible = (13, 24)
# possible = (13, 25)
# possible = (13, 26)
# possible = (13, 27)
# possible = (14, 1)
# necessary = (14, 2)
# possible = (14, 3)
# possible = (14, 4)
# possible = (14, 5)
# possible = (14, 6)
# possible = (14, 7)
# possible = (14, 8)
# possible = (14, 9)
# possible = (14, 10)
# possible = (14, 11)
# possible = (14, 12)
# possible = (14, 13)
# possible = (14, 15)
# possible = (14, 16)
# possible = (14, 17)
# possible = (14, 18)
# necessary = (14, 19)
# possible = (14, 20)
# possible = (14, 21)
# possible = (14, 22)
# possible = (14, 23)
# possible = (14, 24)
# necessary = (14, 25)
# possible = (14, 26)
# possible = (14, 27)
# possible = (15, 1)
# possible = (15, 2)
# possible = (15, 3)
# possible = (15, 4)
# possible = (15, 5)
# possible = (15, 6)
# possible = (15, 7)
# possible = (15, 8)
# possible = (15, 9)
# possible = (15, 10)
# possible = (15, 11)
# possible = (15, 12)
# possible = (15, 13)
# possible = (15, 14)
# possible = (15, 16)
# possible = (15, 17)
# possible = (15, 18)
# possible = (15, 19)
# possible = (15, 20)
# possible = (15, 21)
# possible = (15, 22)
# possible = (15, 23)
# possible = (15, 24)
# possible = (15, 25)
# possible = (15, 26)
# possible = (15, 27)
# possible = (16, 1)
# possible = (16, 2)
# possible = (16, 3)
# possible = (16, 4)
# possible = (16, 5)
# possible = (16, 6)
# possible = (16, 7)
# possible = (16, 8)
# possible = (16, 9)
# possible = (16, 10)
# possible = (16, 11)
# possible = (16, 12)
# necessary = (16, 13)
# possible = (16, 14)
# possible = (16, 15)
# possible = (16, 17)
# possible = (16, 18)
# possible = (16, 19)
# possible = (16, 20)
# possible = (16, 21)
# possible = (16, 22)
# possible = (16, 23)
# possible = (16, 24)
# possible = (16, 25)
# possible = (16, 26)
# possible = (16, 27)
# possible = (17, 1)
# possible = (17, 2)
# possible = (17, 3)
# possible = (17, 4)
# possible = (17, 5)
# possible = (17, 6)
# possible = (17, 7)
# possible = (17, 8)
# possible = (17, 9)
# possible = (17, 10)
# possible = (17, 11)
# possible = (17, 12)
# possible = (17, 13)
# possible = (17, 14)
# possible = (17, 15)
# possible = (17, 16)
# possible = (17, 18)
# possible = (17, 19)
# possible = (17, 20)
# possible = (17, 21)
# possible = (17, 22)
# possible = (17, 23)
# possible = (17, 24)
# possible = (17, 25)
# possible = (17, 26)
# possible = (17, 27)
# possible = (18, 1)
# possible = (18, 2)
# possible = (18, 3)
# possible = (18, 4)
# possible = (18, 5)
# possible = (18, 6)
# possible = (18, 7)
# possible = (18, 8)
# possible = (18, 9)
# possible = (18, 10)
# possible = (18, 11)
# possible = (18, 12)
# possible = (18, 13)
# possible = (18, 14)
# possible = (18, 15)
# possible = (18, 16)
# possible = (18, 17)
# possible = (18, 19)
# possible = (18, 20)
# possible = (18, 21)
# possible = (18, 22)
# possible = (18, 23)
# possible = (18, 24)
# possible = (18, 25)
# possible = (18, 26)
# necessary = (18, 27)
# possible = (19, 1)
# possible = (19, 2)
# possible = (19, 3)
# possible = (19, 4)
# possible = (19, 5)
# possible = (19, 6)
# possible = (19, 7)
# possible = (19, 8)
# possible = (19, 9)
# possible = (19, 10)
# possible = (19, 11)
# possible = (19, 12)
# possible = (19, 13)
# possible = (19, 14)
# possible = (19, 15)
# possible = (19, 16)
# possible = (19, 17)
# possible = (19, 18)
# possible = (19, 20)
# possible = (19, 21)
# possible = (19, 22)
# possible = (19, 23)
# possible = (19, 24)
# necessary = (19, 25)
# possible = (19, 26)
# possible = (19, 27)
# possible = (20, 1)
# possible = (20, 2)
# possible = (20, 3)
# possible = (20, 4)
# possible = (20, 5)
# possible = (20, 6)
# possible = (20, 7)
# possible = (20, 8)
# possible = (20, 9)
# possible = (20, 10)
# possible = (20, 11)
# possible = (20, 12)
# possible = (20, 13)
# possible = (20, 14)
# possible = (20, 15)
# possible = (20, 16)
# possible = (20, 17)
# possible = (20, 18)
# possible = (20, 19)
# possible = (20, 21)
# possible = (20, 22)
# possible = (20, 23)
# possible = (20, 24)
# possible = (20, 25)
# necessary = (20, 26)
# possible = (20, 27)
# possible = (21, 1)
# possible = (21, 2)
# possible = (21, 3)
# possible = (21, 4)
# possible = (21, 5)
# possible = (21, 6)
# possible = (21, 7)
# possible = (21, 8)
# possible = (21, 9)
# possible = (21, 10)
# possible = (21, 11)
# possible = (21, 12)
# possible = (21, 13)
# possible = (21, 14)
# possible = (21, 15)
# possible = (21, 16)
# possible = (21, 17)
# possible = (21, 18)
# possible = (21, 19)
# possible = (21, 20)
# possible = (21, 22)
# possible = (21, 23)
# possible = (21, 24)
# possible = (21, 25)
# possible = (21, 26)
# possible = (21, 27)
# possible = (22, 1)
# possible = (22, 2)
# possible = (22, 3)
# possible = (22, 4)
# possible = (22, 5)
# possible = (22, 6)
# possible = (22, 7)
# possible = (22, 8)
# possible = (22, 9)
# possible = (22, 10)
# possible = (22, 11)
# possible = (22, 12)
# possible = (22, 13)
# possible = (22, 14)
# possible = (22, 15)
# possible = (22, 16)
# possible = (22, 17)
# possible = (22, 18)
# necessary = (22, 19)
# possible = (22, 20)
# possible = (22, 21)
# possible = (22, 23)
# possible = (22, 24)
# necessary = (22, 25)
# possible = (22, 26)
# possible = (22, 27)
# possible = (23, 1)
# possible = (23, 2)
# possible = (23, 3)
# possible = (23, 4)
# possible = (23, 5)
# possible = (23, 6)
# possible = (23, 7)
# possible = (23, 8)
# possible = (23, 9)
# possible = (23, 10)
# possible = (23, 11)
# possible = (23, 12)
# possible = (23, 13)
# possible = (23, 14)
# possible = (23, 15)
# possible = (23, 16)
# possible = (23, 17)
# possible = (23, 18)
# possible = (23, 19)
# possible = (23, 20)
# necessary = (23, 21)
# possible = (23, 22)
# possible = (23, 24)
# possible = (23, 25)
# necessary = (23, 26)
# possible = (23, 27)
# possible = (24, 1)
# possible = (24, 2)
# possible = (24, 3)
# possible = (24, 4)
# possible = (24, 5)
# possible = (24, 6)
# possible = (24, 7)
# possible = (24, 8)
# possible = (24, 9)
# possible = (24, 10)
# possible = (24, 11)
# possible = (24, 12)
# possible = (24, 13)
# possible = (24, 14)
# possible = (24, 15)
# possible = (24, 16)
# possible = (24, 17)
# possible = (24, 18)
# possible = (24, 19)
# possible = (24, 20)
# possible = (24, 21)
# possible = (24, 22)
# possible = (24, 23)
# possible = (24, 25)
# possible = (24, 26)
# necessary = (24, 27)
# possible = (25, 1)
# possible = (25, 2)
# possible = (25, 3)
# possible = (25, 4)
# possible = (25, 5)
# possible = (25, 6)
# possible = (25, 7)
# possible = (25, 8)
# possible = (25, 9)
# possible = (25, 10)
# possible = (25, 11)
# possible = (25, 12)
# possible = (25, 13)
# possible = (25, 14)
# possible = (25, 15)
# possible = (25, 16)
# possible = (25, 17)
# possible = (25, 18)
# necessary = (25, 19)
# possible = (25, 20)
# possible = (25, 21)
# possible = (25, 22)
# possible = (25, 23)
# possible = (25, 24)
# possible = (25, 26)
# possible = (25, 27)
# possible = (26, 1)
# possible = (26, 2)
# possible = (26, 3)
# possible = (26, 4)
# possible = (26, 5)
# possible = (26, 6)
# possible = (26, 7)
# possible = (26, 8)
# possible = (26, 9)
# possible = (26, 10)
# possible = (26, 11)
# possible = (26, 12)
# possible = (26, 13)
# possible = (26, 14)
# possible = (26, 15)
# possible = (26, 16)
# possible = (26, 17)
# possible = (26, 18)
# possible = (26, 19)
# possible = (26, 20)
# possible = (26, 21)
# possible = (26, 22)
# possible = (26, 23)
# possible = (26, 24)
# possible = (26, 25)
# possible = (26, 27)
# possible = (27, 1)
# possible = (27, 2)
# possible = (27, 3)
# possible = (27, 4)
# possible = (27, 5)
# possible = (27, 6)
# possible = (27, 7)
# possible = (27, 8)
# possible = (27, 9)
# possible = (27, 10)
# possible = (27, 11)
# possible = (27, 12)
# possible = (27, 13)
# possible = (27, 14)
# possible = (27, 15)
# possible = (27, 16)
# possible = (27, 17)
# possible = (27, 18)
# possible = (27, 19)
# possible = (27, 20)
# possible = (27, 21)
# possible = (27, 22)
# possible = (27, 23)
# possible = (27, 24)
# possible = (27, 25)
# possible = (27, 26)
