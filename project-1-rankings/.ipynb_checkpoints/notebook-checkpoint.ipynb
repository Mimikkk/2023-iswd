# %% [markdown]
# # Projekt 1 - Ranking scenariuszy zarządzania odpadami radioaktywnymi
# ## Autorzy
# - Daniel Zdancewicz [145317]
# - Alex Terentowicz [145419]
#
# ## Opis
# Zadaniem projektu jest stworzenie rankingu różnych scenariuszy zarządzania odpadami radioaktywnymi
# z wykorzystaniem odpornej regresji porządkowej. Będziemy bazować na zbiorze danych opisanym w pracy
# [Nuclear waste management: an application of the multicriteria PROMETHEE methods](./paper.pdf)
#
# Wyobraźmy sobie, że jesteśmy instytucją zajmującą się utylizacją odpadów radioaktywnych. Naszym
# zadaniem jest zaproponowanie modelu utylizacji takich odpadów dla 30-letniego programu nuklearnego.
# Wybrano 3 miejsca na potencjalne składowisko, 3 scenariusze czasowe oraz 3 modele finansowania. Ze
# względu na to, że ostatecznie klient może się nie zgodzić na optymalną dla nas strategię, dlatego chcielibyśmy uzyskać pełne rankingi wszystkich opcji. Zespół ekspertów ocenił wszystkie możliwe scenariusze przez nas rozważane (dane znajdują się w pliku [Nuclear waste management.csv](./resources/nuclear-waste.csv))
#
# ## Informacja preferencyjna
#
# Wybrane i oceniane pary wariantów znajdują się w pliku [preferential-information.csv](./resources/preferential-information.csv).
# Grupy, do których należą autorzy to 1 i 4, które definiują preferencję.
#
# Rozważane preferencje:
# - Wydajność produkcji elektrycznej wzrośnie.
# - Ostrożny inwestor, który nie chce ryzykować.

# %% [markdown]
# ## Zadanie 1 — UTA — Ocena wariantów
# ### Informacja o informacji preferencyjnej.
# Preferencje zostały na podstawie przynależności do grupy 1 i 4.
# Te grupy definiują preferencję:
# - Wydajność produkcji elektrycznej wzrośnie.
# - Ostrożny inwestor, który nie chce ryzykować.
#
# W zadaniu były dostępne 4 kryteria oceny (wszystkie są typu koszt):
# - C1 — Finansowe koszty całkowite (The total financial cost)
# - C2 — Koszty finansowe przez aktualnego konsumenta (The financial cost incurred by the current consumer)
# - C3 — Koszty wspierane przez przyszłego konsumenta (The financial cost supported by the future consumer)
# - C4 — Ryzyko kosztów finansowych (Financial risk due to overcosts)
#
# Co zostało zinterpretowane jako minimalizacja kryterium 4 i przyzwolenie na zaniedbania kryterium 3.
# Minimalizacja czwartego kryterium (C4: ryzyko kosztów finansowych) jest zgodna z preferencją ostrożnego inwestora, który nie pragnie podejmować nadmiernego ryzyka. Tymczasem zaniedbywanie trzeciego kryterium (C3: koszty wspierane przez przyszłych konsumentów) sugeruje pomijanie kosztów przyszłościowych z racji optymistycznej prognozy wzrostu wydajności w produkcji energii elektrycznej. W rezultacie modelowanie ważności kryteriów można przedstawić jako C4 >= C1 ~ C2 >= C3.
#
# Tę hierarchię można zinterpretować następująco: pierwszym priorytetem jest minimalizacja ryzyka kosztów finansowych, aby zaspokoić potrzeby ostrożnego inwestora. Drugą preferencją są koszty całkowite, które są równoważne z trzecim priorytetem, czyli kosztami ponoszonymi przez obecnych konsumentów. W końcu najmniej ważne są koszty wspierane przez przyszłych konsumentów, ze względu na optymistyczne prognozy wzrostu wydajności w sektorze produkcji energii elektrycznej.

# %% [markdown]
# ### Ocena wybranych par wariantów
# Przedstawione niżej 5 par wariantów wchodzące do porównań zostały wybrane na podstawie informacji preferencyjnej (5,12,33) oraz predefiniowane (24,25) według indeksów autorów.
#
# | Para | Indeks | C1   | C2   | C3   | C4   |
# |:----:|:------:|------|------|------|------|
# | 05-1 |   15   | 0.87 | 0.03 | 1.00 | 0.61 |
# | 05-2 |   26   | 0.71 | 0.25 | 0.88 | 0.67 |
# | 12-1 |   01   | 0.60 | 0.93 | 0.00 | 0.73 |
# | 12-2 |   05   | 0.62 | 0.40 | 0.56 | 0.50 |
# | 24-1 |   06   | 0.78 | 0.27 | 0.71 | 0.50 |
# | 24-2 |   08   | 0.64 | 0.44 | 0.54 | 0.54 |
# | 25-1 |   07   | 0.40 | 0.90 | 0.00 | 0.82 |
# | 25-2 |   21   | 0.83 | 0.25 | 0.80 | 0.65 |
# | 33-1 |   03   | 1.00 | 0.45 | 0.57 | 0.50 |
# | 33-2 |   27   | 0.80 | 0.06 | 1.00 | 0.67 |
#
# **Ocena par wariantów**:
# Na podstawie przeprowadzoną analizę, najkorzystniejszymi opcją okazały się warianty 05, 08, 06, 03 z uwzględnieniem niższych kosztów finansowych w przypadku indeksu 08 w porównaniu do indeksów 06 i 03. Kolejno, preferowane są indeksy 06, a następnie 03, 15 i 21. Warianty o indeksach 27 i 26 wykazują zbliżone do siebie charakterystyki, za to na końcu rankingu umieszczono indeksy 01 oraz 07. Wyodrębnienie takiego układu hierarchii preferencyjnej opiera się głównie na dążeniu do minimalizacji ryzyka oraz ograniczenia kosztów finansowych bez silnego uwzględniania kosztów przyszłych.
#
# **Ostateczny ranking preferencyjny**:
# 05 > 08 > 06 > 03 > 15 > 21 = 27 = 26 > 01 > 07

# %% [markdown]
# ### Problem programowania matematycznego liniowego

# %% [markdown]
# ### Opis
# Do odnalezienia rankingu został zdefiniowany problem programowania matematycznego polegający na rozwiązaniu problemu regresji porządkowej.
#
# Problem regresji porządkowej poszukuje takiej funkcji, która umożliwia na odczytanie wartości całkowitej, dla każdego z wariantów.
#
# Sformułowanie problemu matematycznego uwzględnia trzy typy ograniczeń:
# - Odtworzenie rankingu referencyjnego, poprzez przemianowanie na sumę użyteczności cząstkowych odpowiadającym wariantom.
# - Monotoniczność wartości ( w przypadku naszych kosztów jest to funkcja nierosnąca).
# - Normalizacja wartości do przedziału [0,1].

# %%
from pulp import *
from itertools import pairwise
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

def flatten(it):
  yield from (element for iterable in it for element in iterable)

def exhaust(it): return list(it)

def accessor(value: float) -> int:
  if isinstance(value, pd.Series):
    return (value * 100).astype(np.uint8)
  return int(value * 100)

# %%
def read_variants() -> pd.DataFrame:
  return pd.read_csv("resources/nuclear-waste.csv", index_col=0)

def variant_constraint(utilities, variants, va, vb, epsilon=None):
  (a1, a2, a3, a4) = accessor(variants.loc[va])
  (b1, b2, b3, b4) = accessor(variants.loc[vb])
  (u1, u2, u3, u4) = utilities

  if epsilon is None:
    return (u1[a1] + u2[a2] + u3[a3] + u4[a4] ==
            u1[b1] + u2[b2] + u3[b3] + u4[b4])
  return (u1[a1] + u2[a2] + u3[a3] + u4[a4] >=
          u1[b1] + u2[b2] + u3[b3] + u4[b4] + epsilon)

def find_extremes(variants):
  return [
    accessor(variants[criterion].max())
    for criterion in variants
  ], [
    accessor(variants[criterion].min())
    for criterion in variants
  ]

def create_epsilon(): return LpVariable("epsilon", 0)

def create_utilities(): return [[
  LpVariable(f"u{criterion}_{i:03d}", lowBound=0, upBound=1)
  for i in range(0, 100 + 1)
] for criterion in range(4)]

# %%
variants = read_variants()

def create_ordinal_problem(variants):
  model = LpProblem("ordinal-regression", LpMaximize)

  # 05 > 08 > 06 > 03 > 15 > 21 = 27 = 26 > 01 > 07
  references = [
    (5, 8, epsilon),
    (8, 6, epsilon),
    (6, 3, epsilon),
    (3, 15, epsilon),
    (15, 21, epsilon),
    (21, 27),
    (27, 26),
    (26, 1, epsilon),
    (1, 7, epsilon)
  ]
  # Odtworzenie rankingu referencyjnego
  for reference in references:
    model.add(variant_constraint(utilities, variants, *reference))

  # Warunek normalizacji — Typ koszt
  (worsts, bests) = find_extremes(variants)
  for (i, worst) in enumerate(worsts):
    model.add(utilities[i][worst] == 0)

  model.add(
    sum(utilities[i][best] for (i, best) in enumerate(bests))
    == 1
  )

  # Warunek monotoniczności — Typ koszt
  for (criterion, values) in enumerate([
    sorted(set(accessor(variants[criterion])))
    for criterion in variants
  ]):
    for value in values:
      model.add(utilities[criterion][value] >= 0)

    for (v1, v2) in pairwise(values):
      model.add(utilities[criterion][v1] >= utilities[criterion][v2])
  return model

# %%
# Funkcja celu
epsilon = create_epsilon()
utilities = create_utilities()

model = create_ordinal_problem(variants)
model.setObjective(epsilon)
model.solve()

print(f'status: {model.status}, {LpStatus[model.status]}')
print(f"Objective: {model.objective.value()}")
# Out:
# status: 1, Optimal
# Objective: 0.11111111

# %% [markdown]
# ### Ranking wariantów przy użyciu metody UTA

# %%
def show_plot(utilities):
  figure, axes = plt.subplots(2, 2)
  figure.tight_layout(pad=2)

  for (crit, criterion) in enumerate(variants):
    axis = axes[divmod(crit, 2)]
    a_values = sorted(set(accessor(variants[criterion])))
    u_values = [round(value.value(), 3) for i, value in enumerate(utilities[crit]) if i in a_values]

    axis.plot([value / 100 for value in a_values], u_values)
    axis.set_title(criterion)

  plt.show()

# %%
show_plot(utilities)

# %% [markdown]
# ### Ocena spójności otrzymanego rankingu z informacją preferencyjną dla kilku wybranych niereferencyjnych

# %%
from copy import deepcopy
def create_ranking(utilities):
  ranking = pd.DataFrame(deepcopy(variants))

  for (crit, criterion) in enumerate(ranking):
    ranking[f"U({criterion})"] = [0 for _ in range(len(variants))]
  ranking["U"] = [0 for _ in range(len(variants))]

  for (crit, criterion) in enumerate(variants):
    for variant in variants.index:
      u_arg = accessor(variants[criterion][variant])
      ranking[f"U({criterion})"][variant] += round(utilities[crit][u_arg].value(), 3)

  for variant in variants.index:
    ranking["U"][variant] = np.sum(ranking.loc[variant][5:])

  return ranking.sort_values('U', ascending=False)

# %%
create_ranking(utilities)
# Out:
# C:\Users\HououinKyouma\AppData\Local\Temp\ipykernel_23072\3837284645.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking[f"U({criterion})"][variant] += round(utilities[crit][u_arg].value(), 3)
# C:\Users\HououinKyouma\AppData\Local\Temp\ipykernel_23072\3837284645.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking["U"][variant] = np.sum(ranking.loc[variant][5:])
#          C1    C2    C3    C4  U(C1)  U(C2)  U(C3)  U(C4)      U
# index
# 5      0.62  0.40  0.56  0.50      0  0.333  0.222  0.444  0.999
# 8      0.64  0.44  0.54  0.54      0  0.222  0.222  0.444  0.888
# 6      0.78  0.27  0.71  0.50      0  0.333  0.000  0.444  0.777
# 12     0.74  0.25  0.80  0.49      0  0.333  0.000  0.444  0.777
# 11     0.61  0.54  0.38  0.49      0  0.000  0.222  0.444  0.666
# 3      1.00  0.45  0.57  0.50      0  0.000  0.222  0.444  0.666
# 2      0.66  0.55  0.45  0.49      0  0.000  0.222  0.444  0.666
# 9      0.65  0.30  0.71  0.55      0  0.333  0.000  0.222  0.555
# 15     0.87  0.03  1.00  0.61      0  0.333  0.000  0.222  0.555
# 17     0.68  0.40  0.65  0.60      0  0.333  0.000  0.222  0.555
# 18     0.76  0.06  1.00  0.60      0  0.333  0.000  0.222  0.555
# 23     0.59  0.24  0.70  0.63      0  0.333  0.000  0.111  0.444
# 21     0.83  0.25  0.80  0.65      0  0.333  0.000  0.111  0.444
# 24     0.73  0.03  1.00  0.63      0  0.333  0.000  0.111  0.444
# 26     0.71  0.25  0.88  0.67      0  0.333  0.000  0.111  0.444
# 20     0.64  0.22  0.81  0.65      0  0.333  0.000  0.111  0.444
# 14     0.69  0.49  0.56  0.61      0  0.000  0.222  0.222  0.444
# 27     0.80  0.06  1.00  0.67      0  0.333  0.000  0.111  0.444
# 10     0.45  0.86  0.00  0.73      0  0.000  0.222  0.111  0.333
# 1      0.60  0.93  0.00  0.73      0  0.000  0.222  0.111  0.333
# 19     0.35  0.91  0.00  0.98      0  0.000  0.222  0.000  0.222
# 16     0.44  0.95  0.00  0.90      0  0.000  0.222  0.000  0.222
# 13     0.48  0.97  0.00  0.91      0  0.000  0.222  0.000  0.222
# 22     0.32  0.83  0.00  0.94      0  0.000  0.222  0.000  0.222
# 7      0.40  0.90  0.00  0.82      0  0.000  0.222  0.000  0.222
# 4      0.48  0.87  0.00  0.75      0  0.000  0.222  0.000  0.222
# 25     0.34  1.00  1.00  1.00      0  0.000  0.000  0.000  0.000

# %% [markdown]
# Ranking preferencyjny został prawie w pełni odwzorowany. Jedyna różnica to, że wariant 26 jest przed wariantem 27. Również wyniki są w przedziale [0,1].
#
# Najlepszą strategią okazuje się wariant 5, a najgorszą 25.
# Wariant najlepszy ma wagi [0,0.3(3),0.2(2),0.4(4)].
# Wariant najgorszy ma wagi [0,0,0,0].

# %% [markdown]
# ## Zadanie 2 — UTA GMS — Analiza koniecznych relacji

# %%
def gms(a: int, b: int, seek_necessary: bool) -> LpProblem:
  model = create_ordinal_problem(variants)
  model.setObjective(epsilon)

  if seek_necessary:
    model.add(variant_constraint(utilities, variants, b, a, epsilon))
  else:
    model.add(variant_constraint(utilities, variants, a, b))

  model.solve()

  return model.objective.value(), model.status

relations = set()
for i in range(1, 27 + 1):
  epsilon = create_epsilon()
  utilities = create_utilities()

  for j in range(1, 27 + 1):
    if i == j: continue
    result, status = gms(i, j, seek_necessary=True)
    if result <= 0 or LpStatus[status] == 'Infeasible':
      print(f'necessary : {i:02d}, {j:02d}')
      relations.add((i, j))

    result, status = gms(i, j, seek_necessary=False)
    if result >= 0 and LpStatus[status] == 'Optimal':
      print(f'possible  : {i:02d}, {j:02d}')
# Out:
# possible  : 01, 02
# possible  : 01, 03
# possible  : 01, 04
# possible  : 01, 05
# possible  : 01, 06
# necessary : 01, 07
# possible  : 01, 07
# possible  : 01, 08
# possible  : 01, 09
# possible  : 01, 10
# possible  : 01, 11
# possible  : 01, 12
# necessary : 01, 13
# possible  : 01, 13
# possible  : 01, 14
# possible  : 01, 15
# necessary : 01, 16
# possible  : 01, 16
# possible  : 01, 17
# possible  : 01, 18
# possible  : 01, 19
# possible  : 01, 20
# possible  : 01, 21
# possible  : 01, 22
# possible  : 01, 23
# possible  : 01, 24
# possible  : 01, 25
# possible  : 01, 26
# possible  : 01, 27
# possible  : 02, 01
# possible  : 02, 03
# possible  : 02, 04
# possible  : 02, 05
# possible  : 02, 06
# possible  : 02, 07
# possible  : 02, 08
# possible  : 02, 09
# possible  : 02, 10
# possible  : 02, 11
# possible  : 02, 12
# possible  : 02, 13
# possible  : 02, 14
# possible  : 02, 15
# possible  : 02, 16
# possible  : 02, 17
# possible  : 02, 18
# possible  : 02, 19
# possible  : 02, 20
# possible  : 02, 21
# possible  : 02, 22
# possible  : 02, 23
# possible  : 02, 24
# possible  : 02, 25
# possible  : 02, 26
# possible  : 02, 27
# necessary : 03, 01
# possible  : 03, 01
# possible  : 03, 02
# possible  : 03, 04
# possible  : 03, 05
# possible  : 03, 06
# necessary : 03, 07
# possible  : 03, 07
# possible  : 03, 08
# possible  : 03, 09
# possible  : 03, 10
# possible  : 03, 11
# possible  : 03, 12
# necessary : 03, 13
# possible  : 03, 13
# possible  : 03, 14
# necessary : 03, 15
# possible  : 03, 15
# necessary : 03, 16
# possible  : 03, 16
# possible  : 03, 17
# possible  : 03, 18
# possible  : 03, 19
# possible  : 03, 20
# necessary : 03, 21
# possible  : 03, 21
# possible  : 03, 22
# possible  : 03, 23
# possible  : 03, 24
# possible  : 03, 25
# necessary : 03, 26
# possible  : 03, 26
# necessary : 03, 27
# possible  : 03, 27
# possible  : 04, 01
# possible  : 04, 02
# possible  : 04, 03
# possible  : 04, 05
# possible  : 04, 06
# possible  : 04, 07
# possible  : 04, 08
# possible  : 04, 09
# possible  : 04, 10
# possible  : 04, 11
# possible  : 04, 12
# necessary : 04, 13
# possible  : 04, 13
# possible  : 04, 14
# possible  : 04, 15
# possible  : 04, 16
# possible  : 04, 17
# possible  : 04, 18
# possible  : 04, 19
# possible  : 04, 20
# possible  : 04, 21
# possible  : 04, 22
# possible  : 04, 23
# possible  : 04, 24
# possible  : 04, 25
# possible  : 04, 26
# possible  : 04, 27
# necessary : 05, 01
# possible  : 05, 01
# possible  : 05, 02
# necessary : 05, 03
# possible  : 05, 03
# possible  : 05, 04
# necessary : 05, 06
# possible  : 05, 06
# necessary : 05, 07
# possible  : 05, 07
# necessary : 05, 08
# possible  : 05, 08
# possible  : 05, 09
# possible  : 05, 10
# possible  : 05, 11
# possible  : 05, 12
# necessary : 05, 13
# possible  : 05, 13
# necessary : 05, 14
# possible  : 05, 14
# necessary : 05, 15
# possible  : 05, 15
# necessary : 05, 16
# possible  : 05, 16
# necessary : 05, 17
# possible  : 05, 17
# possible  : 05, 18
# possible  : 05, 19
# possible  : 05, 20
# necessary : 05, 21
# possible  : 05, 21
# possible  : 05, 22
# possible  : 05, 23
# necessary : 05, 24
# possible  : 05, 24
# possible  : 05, 25
# necessary : 05, 26
# possible  : 05, 26
# necessary : 05, 27
# possible  : 05, 27
# necessary : 06, 01
# possible  : 06, 01
# possible  : 06, 02
# necessary : 06, 03
# possible  : 06, 03
# possible  : 06, 04
# possible  : 06, 05
# necessary : 06, 07
# possible  : 06, 07
# possible  : 06, 08
# possible  : 06, 09
# possible  : 06, 10
# possible  : 06, 11
# possible  : 06, 12
# necessary : 06, 13
# possible  : 06, 13
# possible  : 06, 14
# necessary : 06, 15
# possible  : 06, 15
# necessary : 06, 16
# possible  : 06, 16
# possible  : 06, 17
# possible  : 06, 18
# possible  : 06, 19
# possible  : 06, 20
# necessary : 06, 21
# possible  : 06, 21
# possible  : 06, 22
# possible  : 06, 23
# possible  : 06, 24
# possible  : 06, 25
# necessary : 06, 26
# possible  : 06, 26
# necessary : 06, 27
# possible  : 06, 27
# possible  : 07, 01
# possible  : 07, 02
# possible  : 07, 03
# possible  : 07, 04
# possible  : 07, 05
# possible  : 07, 06
# possible  : 07, 08
# possible  : 07, 09
# possible  : 07, 10
# possible  : 07, 11
# possible  : 07, 12
# necessary : 07, 13
# possible  : 07, 13
# possible  : 07, 14
# possible  : 07, 15
# necessary : 07, 16
# possible  : 07, 16
# possible  : 07, 17
# possible  : 07, 18
# possible  : 07, 19
# possible  : 07, 20
# possible  : 07, 21
# possible  : 07, 22
# possible  : 07, 23
# possible  : 07, 24
# possible  : 07, 25
# possible  : 07, 26
# possible  : 07, 27
# necessary : 08, 01
# possible  : 08, 01
# possible  : 08, 02
# necessary : 08, 03
# possible  : 08, 03
# possible  : 08, 04
# possible  : 08, 05
# necessary : 08, 06
# possible  : 08, 06
# necessary : 08, 07
# possible  : 08, 07
# possible  : 08, 09
# possible  : 08, 10
# possible  : 08, 11
# possible  : 08, 12
# necessary : 08, 13
# possible  : 08, 13
# necessary : 08, 14
# possible  : 08, 14
# necessary : 08, 15
# possible  : 08, 15
# necessary : 08, 16
# possible  : 08, 16
# possible  : 08, 17
# possible  : 08, 18
# possible  : 08, 19
# possible  : 08, 20
# necessary : 08, 21
# possible  : 08, 21
# possible  : 08, 22
# possible  : 08, 23
# possible  : 08, 24
# possible  : 08, 25
# necessary : 08, 26
# possible  : 08, 26
# necessary : 08, 27
# possible  : 08, 27
# possible  : 09, 01
# possible  : 09, 02
# possible  : 09, 03
# possible  : 09, 04
# possible  : 09, 05
# possible  : 09, 06
# possible  : 09, 07
# possible  : 09, 08
# possible  : 09, 10
# possible  : 09, 11
# possible  : 09, 12
# possible  : 09, 13
# possible  : 09, 14
# possible  : 09, 15
# possible  : 09, 16
# possible  : 09, 17
# possible  : 09, 18
# possible  : 09, 19
# possible  : 09, 20
# possible  : 09, 21
# possible  : 09, 22
# possible  : 09, 23
# possible  : 09, 24
# possible  : 09, 25
# possible  : 09, 26
# possible  : 09, 27
# necessary : 10, 01
# possible  : 10, 01
# possible  : 10, 02
# possible  : 10, 03
# necessary : 10, 04
# possible  : 10, 04
# possible  : 10, 05
# possible  : 10, 06
# necessary : 10, 07
# possible  : 10, 07
# possible  : 10, 08
# possible  : 10, 09
# possible  : 10, 11
# possible  : 10, 12
# necessary : 10, 13
# possible  : 10, 13
# possible  : 10, 14
# possible  : 10, 15
# necessary : 10, 16
# possible  : 10, 16
# possible  : 10, 17
# possible  : 10, 18
# possible  : 10, 19
# possible  : 10, 20
# possible  : 10, 21
# possible  : 10, 22
# possible  : 10, 23
# possible  : 10, 24
# possible  : 10, 25
# possible  : 10, 26
# possible  : 10, 27
# possible  : 11, 01
# necessary : 11, 02
# possible  : 11, 02
# possible  : 11, 03
# possible  : 11, 04
# possible  : 11, 05
# possible  : 11, 06
# possible  : 11, 07
# possible  : 11, 08
# possible  : 11, 09
# possible  : 11, 10
# possible  : 11, 12
# possible  : 11, 13
# possible  : 11, 14
# possible  : 11, 15
# possible  : 11, 16
# possible  : 11, 17
# possible  : 11, 18
# possible  : 11, 19
# possible  : 11, 20
# possible  : 11, 21
# possible  : 11, 22
# possible  : 11, 23
# possible  : 11, 24
# possible  : 11, 25
# possible  : 11, 26
# possible  : 11, 27
# necessary : 12, 01
# possible  : 12, 01
# possible  : 12, 02
# possible  : 12, 03
# possible  : 12, 04
# possible  : 12, 05
# possible  : 12, 06
# necessary : 12, 07
# possible  : 12, 07
# possible  : 12, 08
# possible  : 12, 09
# possible  : 12, 10
# possible  : 12, 11
# necessary : 12, 13
# possible  : 12, 13
# possible  : 12, 14
# possible  : 12, 15
# necessary : 12, 16
# possible  : 12, 16
# possible  : 12, 17
# possible  : 12, 18
# possible  : 12, 19
# possible  : 12, 20
# necessary : 12, 21
# possible  : 12, 21
# possible  : 12, 22
# possible  : 12, 23
# possible  : 12, 24
# possible  : 12, 25
# necessary : 12, 26
# possible  : 12, 26
# necessary : 12, 27
# possible  : 12, 27
# possible  : 13, 01
# possible  : 13, 02
# possible  : 13, 03
# possible  : 13, 04
# possible  : 13, 05
# possible  : 13, 06
# possible  : 13, 07
# possible  : 13, 08
# possible  : 13, 09
# possible  : 13, 10
# possible  : 13, 11
# possible  : 13, 12
# possible  : 13, 14
# possible  : 13, 15
# possible  : 13, 16
# possible  : 13, 17
# possible  : 13, 18
# possible  : 13, 19
# possible  : 13, 20
# possible  : 13, 21
# possible  : 13, 22
# possible  : 13, 23
# possible  : 13, 24
# possible  : 13, 25
# possible  : 13, 26
# possible  : 13, 27
# possible  : 14, 01
# possible  : 14, 02
# possible  : 14, 03
# possible  : 14, 04
# possible  : 14, 05
# possible  : 14, 06
# possible  : 14, 07
# possible  : 14, 08
# possible  : 14, 09
# possible  : 14, 10
# possible  : 14, 11
# possible  : 14, 12
# possible  : 14, 13
# possible  : 14, 15
# possible  : 14, 16
# possible  : 14, 17
# possible  : 14, 18
# possible  : 14, 19
# possible  : 14, 20
# possible  : 14, 21
# possible  : 14, 22
# possible  : 14, 23
# possible  : 14, 24
# possible  : 14, 25
# possible  : 14, 26
# possible  : 14, 27
# necessary : 15, 01
# possible  : 15, 01
# possible  : 15, 02
# possible  : 15, 03
# possible  : 15, 04
# possible  : 15, 05
# possible  : 15, 06
# necessary : 15, 07
# possible  : 15, 07
# possible  : 15, 08
# possible  : 15, 09
# possible  : 15, 10
# possible  : 15, 11
# possible  : 15, 12
# necessary : 15, 13
# possible  : 15, 13
# possible  : 15, 14
# necessary : 15, 16
# possible  : 15, 16
# possible  : 15, 17
# possible  : 15, 18
# possible  : 15, 19
# possible  : 15, 20
# necessary : 15, 21
# possible  : 15, 21
# possible  : 15, 22
# possible  : 15, 23
# possible  : 15, 24
# possible  : 15, 25
# necessary : 15, 26
# possible  : 15, 26
# necessary : 15, 27
# possible  : 15, 27
# possible  : 16, 01
# possible  : 16, 02
# possible  : 16, 03
# possible  : 16, 04
# possible  : 16, 05
# possible  : 16, 06
# possible  : 16, 07
# possible  : 16, 08
# possible  : 16, 09
# possible  : 16, 10
# possible  : 16, 11
# possible  : 16, 12
# necessary : 16, 13
# possible  : 16, 13
# possible  : 16, 14
# possible  : 16, 15
# possible  : 16, 17
# possible  : 16, 18
# possible  : 16, 19
# possible  : 16, 20
# possible  : 16, 21
# possible  : 16, 22
# possible  : 16, 23
# possible  : 16, 24
# possible  : 16, 25
# possible  : 16, 26
# possible  : 16, 27
# possible  : 17, 01
# possible  : 17, 02
# possible  : 17, 03
# possible  : 17, 04
# possible  : 17, 05
# possible  : 17, 06
# possible  : 17, 07
# possible  : 17, 08
# possible  : 17, 09
# possible  : 17, 10
# possible  : 17, 11
# possible  : 17, 12
# possible  : 17, 13
# possible  : 17, 14
# possible  : 17, 15
# possible  : 17, 16
# possible  : 17, 18
# possible  : 17, 19
# possible  : 17, 20
# possible  : 17, 21
# possible  : 17, 22
# possible  : 17, 23
# possible  : 17, 24
# possible  : 17, 25
# possible  : 17, 26
# possible  : 17, 27
# necessary : 18, 01
# possible  : 18, 01
# possible  : 18, 02
# possible  : 18, 03
# possible  : 18, 04
# possible  : 18, 05
# possible  : 18, 06
# necessary : 18, 07
# possible  : 18, 07
# possible  : 18, 08
# possible  : 18, 09
# possible  : 18, 10
# possible  : 18, 11
# possible  : 18, 12
# necessary : 18, 13
# possible  : 18, 13
# possible  : 18, 14
# possible  : 18, 15
# necessary : 18, 16
# possible  : 18, 16
# possible  : 18, 17
# possible  : 18, 19
# possible  : 18, 20
# necessary : 18, 21
# possible  : 18, 21
# possible  : 18, 22
# possible  : 18, 23
# possible  : 18, 24
# possible  : 18, 25
# necessary : 18, 26
# possible  : 18, 26
# necessary : 18, 27
# possible  : 18, 27
# possible  : 19, 01
# possible  : 19, 02
# possible  : 19, 03
# possible  : 19, 04
# possible  : 19, 05
# possible  : 19, 06
# possible  : 19, 07
# possible  : 19, 08
# possible  : 19, 09
# possible  : 19, 10
# possible  : 19, 11
# possible  : 19, 12
# possible  : 19, 13
# possible  : 19, 14
# possible  : 19, 15
# possible  : 19, 16
# possible  : 19, 17
# possible  : 19, 18
# possible  : 19, 20
# possible  : 19, 21
# possible  : 19, 22
# possible  : 19, 23
# possible  : 19, 24
# possible  : 19, 25
# possible  : 19, 26
# possible  : 19, 27
# necessary : 20, 01
# possible  : 20, 01
# possible  : 20, 02
# possible  : 20, 03
# possible  : 20, 04
# possible  : 20, 05
# possible  : 20, 06
# necessary : 20, 07
# possible  : 20, 07
# possible  : 20, 08
# possible  : 20, 09
# possible  : 20, 10
# possible  : 20, 11
# possible  : 20, 12
# necessary : 20, 13
# possible  : 20, 13
# possible  : 20, 14
# possible  : 20, 15
# necessary : 20, 16
# possible  : 20, 16
# possible  : 20, 17
# possible  : 20, 18
# possible  : 20, 19
# necessary : 20, 21
# possible  : 20, 21
# possible  : 20, 22
# possible  : 20, 23
# possible  : 20, 24
# possible  : 20, 25
# necessary : 20, 26
# possible  : 20, 26
# necessary : 20, 27
# possible  : 20, 27
# necessary : 21, 01
# possible  : 21, 01
# possible  : 21, 02
# possible  : 21, 03
# possible  : 21, 04
# possible  : 21, 05
# possible  : 21, 06
# necessary : 21, 07
# possible  : 21, 07
# possible  : 21, 08
# possible  : 21, 09
# possible  : 21, 10
# possible  : 21, 11
# possible  : 21, 12
# necessary : 21, 13
# possible  : 21, 13
# possible  : 21, 14
# possible  : 21, 15
# necessary : 21, 16
# possible  : 21, 16
# possible  : 21, 17
# possible  : 21, 18
# possible  : 21, 19
# possible  : 21, 20
# possible  : 21, 22
# possible  : 21, 23
# possible  : 21, 24
# possible  : 21, 25
# necessary : 21, 26
# possible  : 21, 26
# necessary : 21, 27
# possible  : 21, 27
# possible  : 22, 01
# possible  : 22, 02
# possible  : 22, 03
# possible  : 22, 04
# possible  : 22, 05
# possible  : 22, 06
# possible  : 22, 07
# possible  : 22, 08
# possible  : 22, 09
# possible  : 22, 10
# possible  : 22, 11
# possible  : 22, 12
# possible  : 22, 13
# possible  : 22, 14
# possible  : 22, 15
# possible  : 22, 16
# possible  : 22, 17
# possible  : 22, 18
# necessary : 22, 19
# possible  : 22, 19
# possible  : 22, 20
# possible  : 22, 21
# possible  : 22, 23
# possible  : 22, 24
# necessary : 22, 25
# possible  : 22, 25
# possible  : 22, 26
# possible  : 22, 27
# necessary : 23, 01
# possible  : 23, 01
# possible  : 23, 02
# possible  : 23, 03
# possible  : 23, 04
# possible  : 23, 05
# possible  : 23, 06
# necessary : 23, 07
# possible  : 23, 07
# possible  : 23, 08
# possible  : 23, 09
# possible  : 23, 10
# possible  : 23, 11
# possible  : 23, 12
# necessary : 23, 13
# possible  : 23, 13
# possible  : 23, 14
# possible  : 23, 15
# necessary : 23, 16
# possible  : 23, 16
# possible  : 23, 17
# possible  : 23, 18
# possible  : 23, 19
# possible  : 23, 20
# necessary : 23, 21
# possible  : 23, 21
# possible  : 23, 22
# possible  : 23, 24
# possible  : 23, 25
# necessary : 23, 26
# possible  : 23, 26
# necessary : 23, 27
# possible  : 23, 27
# necessary : 24, 01
# possible  : 24, 01
# possible  : 24, 02
# possible  : 24, 03
# possible  : 24, 04
# possible  : 24, 05
# possible  : 24, 06
# necessary : 24, 07
# possible  : 24, 07
# possible  : 24, 08
# possible  : 24, 09
# possible  : 24, 10
# possible  : 24, 11
# possible  : 24, 12
# necessary : 24, 13
# possible  : 24, 13
# possible  : 24, 14
# possible  : 24, 15
# necessary : 24, 16
# possible  : 24, 16
# possible  : 24, 17
# possible  : 24, 18
# possible  : 24, 19
# possible  : 24, 20
# necessary : 24, 21
# possible  : 24, 21
# possible  : 24, 22
# possible  : 24, 23
# possible  : 24, 25
# necessary : 24, 26
# possible  : 24, 26
# necessary : 24, 27
# possible  : 24, 27
# possible  : 25, 01
# possible  : 25, 02
# possible  : 25, 03
# possible  : 25, 04
# possible  : 25, 05
# possible  : 25, 06
# possible  : 25, 07
# possible  : 25, 08
# possible  : 25, 09
# possible  : 25, 10
# possible  : 25, 11
# possible  : 25, 12
# possible  : 25, 13
# possible  : 25, 14
# possible  : 25, 15
# possible  : 25, 16
# possible  : 25, 17
# possible  : 25, 18
# possible  : 25, 19
# possible  : 25, 20
# possible  : 25, 21
# possible  : 25, 22
# possible  : 25, 23
# possible  : 25, 24
# possible  : 25, 26
# possible  : 25, 27
# necessary : 26, 01
# possible  : 26, 01
# possible  : 26, 02
# possible  : 26, 03
# possible  : 26, 04
# possible  : 26, 05
# possible  : 26, 06
# necessary : 26, 07
# possible  : 26, 07
# possible  : 26, 08
# possible  : 26, 09
# possible  : 26, 10
# possible  : 26, 11
# possible  : 26, 12
# necessary : 26, 13
# possible  : 26, 13
# possible  : 26, 14
# possible  : 26, 15
# necessary : 26, 16
# possible  : 26, 16
# possible  : 26, 17
# possible  : 26, 18
# possible  : 26, 19
# possible  : 26, 20
# necessary : 26, 21
# possible  : 26, 21
# possible  : 26, 22
# possible  : 26, 23
# possible  : 26, 24
# possible  : 26, 25
# necessary : 26, 27
# possible  : 26, 27
# necessary : 27, 01
# possible  : 27, 01
# possible  : 27, 02
# possible  : 27, 03
# possible  : 27, 04
# possible  : 27, 05
# possible  : 27, 06
# necessary : 27, 07
# possible  : 27, 07
# possible  : 27, 08
# possible  : 27, 09
# possible  : 27, 10
# possible  : 27, 11
# possible  : 27, 12
# necessary : 27, 13
# possible  : 27, 13
# possible  : 27, 14
# possible  : 27, 15
# necessary : 27, 16
# possible  : 27, 16
# possible  : 27, 17
# possible  : 27, 18
# possible  : 27, 19
# possible  : 27, 20
# necessary : 27, 21
# possible  : 27, 21
# possible  : 27, 22
# possible  : 27, 23
# possible  : 27, 24
# possible  : 27, 25
# necessary : 27, 26
# possible  : 27, 26

# %%
alternatives = {f"{i}": [] for i in range(1, 28)}

for (a, b) in relations: alternatives[f"{a}"].append(f"{b}")

indifferences = set()
for alternative in alternatives:
  i = {alternative}
  for n in alternatives[alternative]:
    if alternative in alternatives[n]: i.add(n)
  if len(i) > 1: indifferences.add(frozenset(i))

for indifferent in indifferences:
  newest = []
  for alternative in alternatives:
    if all(e in alternatives[alternative] for e in indifferent):
      new = " ".join(indifferent)

      for element in indifferent: alternatives[alternative].remove(element)
      alternatives[alternative].append(new)

    elif alternative in indifferent:
      newest.extend(filter(lambda x: x not in indifferent, alternatives[alternative]))

  new = ' '.join(indifferent)
  for element in indifferent: del alternatives[element]

  alternatives[new] = list(set(newest))

alternatives
# Out:
# {'1': ['7', '16', '13'],
#  '2': [],
#  '3': ['13', '15', '1', '7', '16', '26 27 21'],
#  '4': ['13'],
#  '5': ['1',
#   '3',
#   '14',
#   '7',
#   '16',
#   '13',
#   '6',
#   '15',
#   '24',
#   '8',
#   '17',
#   '26 27 21'],
#  '6': ['13', '1', '15', '3', '7', '16', '26 27 21'],
#  '7': ['16', '13'],
#  '8': ['13', '6', '15', '1', '3', '14', '7', '16', '26 27 21'],
#  '9': [],
#  '10': ['1', '7', '16', '4', '13'],
#  '11': ['2'],
#  '12': ['13', '1', '7', '16', '26 27 21'],
#  '13': [],
#  '14': [],
#  '15': ['7', '16', '13', '1', '26 27 21'],
#  '16': ['13'],
#  '17': [],
#  '18': ['1', '7', '16', '13', '26 27 21'],
#  '19': [],
#  '20': ['1', '7', '16', '13', '26 27 21'],
#  '22': ['19', '25'],
#  '23': ['13', '1', '7', '16', '26 27 21'],
#  '24': ['1', '7', '16', '13', '26 27 21'],
#  '25': [],
#  '26 27 21': ['13', '16', '7', '1']}

# %%
import networkx as nx
graph = nx.DiGraph()
for (start, nodes) in alternatives.items():
  for destination in nodes: graph.add_edge(start, destination)
  else: graph.add_node(start)
reduced = nx.transitive_reduction(graph)

# %%
import graphviz
clean = graphviz.Digraph()
clean.attr("node", shape="box")
for (a, b) in reduced.edges: clean.edge(a, b)
for node in reduced.nodes: clean.node(node)

# Uncomment to view in browser
clean.render(view=True)
clean

# %% [markdown]
# Uzyskane wyniki wskazują na potrzebę dalszych iteracji w celu pozyskania preferencji użytkowników. Obecnie stwierdzono istnienie kilku wolnych węzłów na diagramie. Istnieje również, trzon, schodzący od 5 do najgorszych wartości, pokazując, że istnieje jednak pewna preferencja w stosunku do wartości.

# %% [markdown]
# ## Zadanie 3 — Konstrukcja reprezentatywnej funkcji użyteczności

# %%
def relational_constraints(va: int, vb: int, variable = None, should_maximize: bool = False) -> None:
  (a1, a2, a3, a4) = accessor(variants.loc[va])
  (b1, b2, b3, b4) = accessor(variants.loc[vb])
  (u1, u2, u3, u4) = utilities

  if should_maximize:
    yield (
        u1[a1] + u2[a2] + u3[a3] + u4[a4] >= u1[b1] + u2[b2] + u3[b3] + u4[b4] + variable
    )
  else:
    yield (
        u1[a1] + u2[a2] + u3[a3] + u4[a4] <= u1[b1] + u2[b2] + u3[b3] + u4[b4] + variable
    )
    yield (
        u1[b1] + u2[b2] + u3[b3] + u4[b4] <= u1[a1] + u2[a2] + u3[a3] + u4[a4] + variable
    )

def create_delta(): return LpVariable("delta")

# %%
epsilon = create_epsilon()
utilities = create_utilities()
delta = create_delta()

model = create_ordinal_problem(variants)

# Big value!
M = 999999
model.setObjective(M * epsilon - delta)

constraints = []
for i in range(1, 28):
  for j in range(1, 28):
    if i == j: continue

    if (i, j) in relations and (j, i) not in relations:
      constraints.extend(relational_constraints(i, j, epsilon, maximize=True))
    if (i, j) not in relations and (j, i) not in relations:
      constraints.extend(relational_constraints(i, j, delta, maximize=False))
      constraints.extend(relational_constraints(j, i, delta, maximize=False))

for constraint in constraints:
  model.add(constraint)

model.solve()

print(f"status: {model.status}, {LpStatus[model.status]}")
print(f"objective: {model.objective.value()}")
# Out:
# status: 1, Optimal
# objective: 90908.181909089

# %%
show_plot(utilities)

# %%
create_ranking(utilities)
# Out:
# C:\Users\HououinKyouma\AppData\Local\Temp\ipykernel_23072\3837284645.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking[f"U({criterion})"][variant] += round(utilities[crit][u_arg].value(), 3)
# C:\Users\HououinKyouma\AppData\Local\Temp\ipykernel_23072\3837284645.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking["U"][variant] = np.sum(ranking.loc[variant][5:])
#          C1    C2    C3    C4  U(C1)  U(C2)  U(C3)  U(C4)      U
# index
# 5      0.62  0.40  0.56  0.50  0.182  0.182      0  0.636  0.818
# 6      0.78  0.27  0.71  0.50  0.000  0.182      0  0.636  0.818
# 8      0.64  0.44  0.54  0.54  0.091  0.182      0  0.636  0.818
# 12     0.74  0.25  0.80  0.49  0.000  0.182      0  0.636  0.818
# 11     0.61  0.54  0.38  0.49  0.182  0.091      0  0.636  0.727
# 3      1.00  0.45  0.57  0.50  0.000  0.091      0  0.636  0.727
# 2      0.66  0.55  0.45  0.49  0.000  0.091      0  0.636  0.727
# 9      0.65  0.30  0.71  0.55  0.000  0.182      0  0.455  0.637
# 15     0.87  0.03  1.00  0.61  0.000  0.182      0  0.455  0.637
# 17     0.68  0.40  0.65  0.60  0.000  0.182      0  0.455  0.637
# 23     0.59  0.24  0.70  0.63  0.182  0.182      0  0.455  0.637
# 18     0.76  0.06  1.00  0.60  0.000  0.182      0  0.455  0.637
# 24     0.73  0.03  1.00  0.63  0.000  0.182      0  0.455  0.637
# 21     0.83  0.25  0.80  0.65  0.000  0.182      0  0.364  0.546
# 26     0.71  0.25  0.88  0.67  0.000  0.182      0  0.364  0.546
# 20     0.64  0.22  0.81  0.65  0.091  0.182      0  0.364  0.546
# 14     0.69  0.49  0.56  0.61  0.000  0.091      0  0.455  0.546
# 27     0.80  0.06  1.00  0.67  0.000  0.182      0  0.364  0.546
# 10     0.45  0.86  0.00  0.73  0.182  0.091      0  0.273  0.364
# 1      0.60  0.93  0.00  0.73  0.182  0.000      0  0.273  0.273
# 7      0.40  0.90  0.00  0.82  0.182  0.000      0  0.182  0.182
# 4      0.48  0.87  0.00  0.75  0.182  0.000      0  0.182  0.182
# 16     0.44  0.95  0.00  0.90  0.182  0.000      0  0.091  0.091
# 22     0.32  0.83  0.00  0.94  0.182  0.091      0  0.000  0.091
# 19     0.35  0.91  0.00  0.98  0.182  0.000      0  0.000  0.000
# 13     0.48  0.97  0.00  0.91  0.182  0.000      0  0.000  0.000
# 25     0.34  1.00  1.00  1.00  0.182  0.000      0  0.000  0.000

# %% [markdown]
# Porównując rankingi, zauważono podobieństwa, jednak różnią się one tym, że wiele elementów zajmuje pierwsze miejsca w porównaniu z poprzednim rozwiązaniem. Konkretnie, w przypadku obecnego rozwiązania, elementy 5, 6, 8 oraz 12 znajdują się na pierwszym miejscu, podczas gdy w poprzednim rozwiązaniu tylko element 5 był na pierwszym miejscu. Z tego wynika, że podejście to jest mniej skłonne do nadmiernego dopasowania się do referencyjnego rankingu.
